# %% [markdown]
# # Ejercicio 12

# %%
# %run ../talktools.py
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'>
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
#     width: 750px;
# }
#
# div #notebook { /* centre the content */
# ...

# %%
#%%cmd
# !cd gitdemo\

# !git status
# !dir
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 6 commits.
#   (use "git push" to publish your local commits)
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	../files/VR23_10Mv02112014.TXT
# 	../files/VR23_10Mv02112014.xls
# 	Lib02_IvanCarrillo.ipynb
# 	Lib03_IvanCarrillo.ipynb
# 	Lib04_IvanCarrillo.ipynb
# 	Lib05_IvanCarrillo.ipynb
# 	Lib06_IvanCarrillo.ipynb
# 	Lib07_IvanCarrillo.ipynb
# 	Lib08_IvanCarrillo.ipynb
# 	Lib09_IvanCarrillo.ipynb
# 	Lib10_IvanCarrillo.ipynb
# 	Lib11_GIT01_IvanCarrillo.ipynb
# 	Lib12_GIT02_IvanCarrillo.ipynb
# 	algunNombre
# 	../../Indice.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)
#  El volumen de la unidad C es Windows
#  El n£mero de serie del volumen es: D6D7-27D9
#
#  Directorio de C:\Users\Ivan\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks
#
# 07/11/2014  08:58 p. m.    <DIR>          .
# 07/11/2014  08:58 p. m.    <DIR>          ..
# ...

# %%
# switchear al branch de experimento
# !cd gitdemo\

# !git branch experimento
# !git checkout experimento
# Out:
# Switched to branch 'experimento'

# %%
# Agregar contenido al branch
# !cd gitdemo\

# !echo "Se me ocurrieron unas ideas locas XD!" > experimentoIvan.txt
# !git add experimentoIvan.txt
# !git commit -a -m"Probando otras cosas nuevas"
# !git slog
# Out:
# [experimento 029591e] Probando otras cosas nuevas
#  1 file changed, 1 insertion(+)
#  create mode 100644 Dia1/notebooks/experimentoIvan.txt
# * 029591e Probando otras cosas nuevas
# * fd7dda1 Eliminando al archivo 2
# * afecb10 Guardado de la edicion al archivo 2
# * 9b1228b Este archivo refleja el segundo commit desde ipynb
# * 9fef2ff Esta mas chido este nombre
# * 759d8d3 Por fin algo de progreso =P
# * 0f62985 Este archivo refleja el primer commit desde ipynb
# *   b1dbd44 Merge branch 'master' of https://github.com/htapia/lania.ipython
# |\
# | * 09261a4 Update README.md
# | * f7d10c4 Update README.md
# * | ab991aa Fixed Index links
# |/
# * 6dc8774 Delete .gitignore
# * dcff105 Update gitignore
# *   c2a7f57 Merge branch 'master' of https://github.com/htapia/lania.ipython
# |\
# | * 6e5dbd8 Update Readme.md
# * | 98c61e5 Organized files and added gitignores
# |/
# * bb402b8 Almost done with notebooks and organization
# ...

# %%
# realizar el checkout
# !cd gitdemo\

# !git checkout master
# !git slog
# Out:
# Your branch is ahead of 'origin/master' by 6 commits.
#   (use "git push" to publish your local commits)
# Switched to branch 'master'
# * fd7dda1 Eliminando al archivo 2
# * afecb10 Guardado de la edicion al archivo 2
# * 9b1228b Este archivo refleja el segundo commit desde ipynb
# * 9fef2ff Esta mas chido este nombre
# * 759d8d3 Por fin algo de progreso =P
# * 0f62985 Este archivo refleja el primer commit desde ipynb
# *   b1dbd44 Merge branch 'master' of https://github.com/htapia/lania.ipython
# |\
# | * 09261a4 Update README.md
# | * f7d10c4 Update README.md
# * | ab991aa Fixed Index links
# |/
# * 6dc8774 Delete .gitignore
# * dcff105 Update gitignore
# *   c2a7f57 Merge branch 'master' of https://github.com/htapia/lania.ipython
# |\
# | * 6e5dbd8 Update Readme.md
# * | 98c61e5 Organized files and added gitignores
# |/
# * bb402b8 Almost done with notebooks and organization
# * 635990e Finished with first part of data analysis in Dia2
# * a8ef187 fixed talktools
# ...

# %%
# realizamos otro commit
# !cd gitdemo/

# !echo "Ahora el trabajo continua en la rama master..." >> archivo-nuevo.txt
# !git commit -a -m"La rama mayor sigue creciendo"
# !git slog
# Out:
# [master e86c514] La rama mayor sigue creciendo
#  1 file changed, 1 insertion(+)
# * e86c514 La rama mayor sigue creciendo
# * fd7dda1 Eliminando al archivo 2
# * afecb10 Guardado de la edicion al archivo 2
# * 9b1228b Este archivo refleja el segundo commit desde ipynb
# * 9fef2ff Esta mas chido este nombre
# * 759d8d3 Por fin algo de progreso =P
# * 0f62985 Este archivo refleja el primer commit desde ipynb
# *   b1dbd44 Merge branch 'master' of https://github.com/htapia/lania.ipython
# |\
# | * 09261a4 Update README.md
# | * f7d10c4 Update README.md
# * | ab991aa Fixed Index links
# |/
# * 6dc8774 Delete .gitignore
# * dcff105 Update gitignore
# *   c2a7f57 Merge branch 'master' of https://github.com/htapia/lania.ipython
# |\
# | * 6e5dbd8 Update Readme.md
# * | 98c61e5 Organized files and added gitignores
# |/
# * bb402b8 Almost done with notebooks and organization
# * 635990e Finished with first part of data analysis in Dia2
# * a8ef187 fixed talktools
# ...

# %%
# !cd gitdemo
# !dir
# Out:
#  El volumen de la unidad C es Windows
#  El n£mero de serie del volumen es: D6D7-27D9
#
#  Directorio de C:\Users\Ivan\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks
#
# 07/11/2014  09:34 p. m.    <DIR>          .
# 07/11/2014  09:34 p. m.    <DIR>          ..
# 07/11/2014  08:18 p. m.    <DIR>          .ipynb_checkpoints
# 01/11/2014  04:57 p. m.                 8 algunNombre
# 07/11/2014  09:45 p. m.               121 archivo-nuevo.txt
# 06/11/2014  12:41 a. m.    <DIR>          gitdemo
# 07/11/2014  08:58 p. m.    <DIR>          html
# 01/11/2014  01:42 p. m.            17,215 Lib00_Esenciales_IPython_Notebook.ipynb
# 01/11/2014  01:54 p. m.            12,255 Lib01_Esenciales_IPython_Notebook.ipynb
# 01/11/2014  11:38 a. m.             8,180 Lib02_Esenciales_IPython_Notebook.ipynb
# 01/11/2014  03:44 p. m.             8,154 Lib02_IvanCarrillo.ipynb
# 01/11/2014  11:38 a. m.             8,366 Lib03_Esenciales_IPython_Notebook.ipynb
# ...

# %%
#Realizar el merge
# !cd gitdemo/
# !git merge experimento
# !git slog
# Out:
# Merge made by the 'recursive' strategy.
#  Dia1/notebooks/experimentoIvan.txt | 1 +
#  1 file changed, 1 insertion(+)
#  create mode 100644 Dia1/notebooks/experimentoIvan.txt
# *   5f31045 Merge branch 'experimento'
# |\
# | * 029591e Probando otras cosas nuevas
# * | e86c514 La rama mayor sigue creciendo
# |/
# * fd7dda1 Eliminando al archivo 2
# * afecb10 Guardado de la edicion al archivo 2
# * 9b1228b Este archivo refleja el segundo commit desde ipynb
# * 9fef2ff Esta mas chido este nombre
# * 759d8d3 Por fin algo de progreso =P
# * 0f62985 Este archivo refleja el primer commit desde ipynb
# *   b1dbd44 Merge branch 'master' of https://github.com/htapia/lania.ipython
# |\
# | * 09261a4 Update README.md
# | * f7d10c4 Update README.md
# * | ab991aa Fixed Index links
# |/
# * 6dc8774 Delete .gitignore
# * dcff105 Update gitignore
# *   c2a7f57 Merge branch 'master' of https://github.com/htapia/lania.ipython
# |\
# | * 6e5dbd8 Update Readme.md
# ...

# %%
# ver el directorio
# !cd gitdemo
# !dir
# Out:
#  El volumen de la unidad C es Windows
#  El n£mero de serie del volumen es: D6D7-27D9
#
#  Directorio de C:\Users\Ivan\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks
#
# 07/11/2014  09:51 p. m.    <DIR>          .
# 07/11/2014  09:51 p. m.    <DIR>          ..
# 07/11/2014  08:18 p. m.    <DIR>          .ipynb_checkpoints
# 01/11/2014  04:57 p. m.                 8 algunNombre
# 07/11/2014  09:45 p. m.               121 archivo-nuevo.txt
# 07/11/2014  09:51 p. m.                42 experimentoIvan.txt
# 06/11/2014  12:41 a. m.    <DIR>          gitdemo
# 07/11/2014  08:58 p. m.    <DIR>          html
# 01/11/2014  01:42 p. m.            17,215 Lib00_Esenciales_IPython_Notebook.ipynb
# 01/11/2014  01:54 p. m.            12,255 Lib01_Esenciales_IPython_Notebook.ipynb
# 01/11/2014  11:38 a. m.             8,180 Lib02_Esenciales_IPython_Notebook.ipynb
# 01/11/2014  03:44 p. m.             8,154 Lib02_IvanCarrillo.ipynb
# ...

# %% [markdown]
# #### Sinesio Ivan Carrillo Heredia
